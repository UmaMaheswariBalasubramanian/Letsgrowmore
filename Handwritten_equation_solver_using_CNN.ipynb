# %%
import numpy as np # linear algebra
import pandas as pd 
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
# !pip install imutils
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imutils in /usr/local/lib/python3.7/dist-packages (0.5.4)

# %%
import numpy as np
import cv2
import os
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, Activation, MaxPool2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.regularizers import l2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd
import imutils
from imutils.contours import sort_contours

# %%
# !wget https://cainvas-static.s3.amazonaws.com/media/user_data/Yuvnish17/data.zip
# !unzip -qo data.zip
# Out:
# --2022-05-28 12:48:47--  https://cainvas-static.s3.amazonaws.com/media/user_data/Yuvnish17/data.zip
# Resolving cainvas-static.s3.amazonaws.com (cainvas-static.s3.amazonaws.com)... 52.219.156.55
# Connecting to cainvas-static.s3.amazonaws.com (cainvas-static.s3.amazonaws.com)|52.219.156.55|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28437489 (27M) [application/x-zip-compressed]
# Saving to: ‘data.zip’
#
# data.zip            100%[===================>]  27.12M  6.79MB/s    in 4.0s
#
# 2022-05-28 12:48:53 (6.79 MB/s) - ‘data.zip’ saved [28437489/28437489]

# %%
x = []
y = []
datadir = 'data/dataset'
for folder in os.listdir(datadir):
    path = os.path.join(datadir, folder)
    for images in os.listdir(path):
        img = cv2.imread(os.path.join(path, images))
        x.append(img)
        y.append(folder)
        
print(len(x))
print(len(y))
print(f'labels : {list(set(y))}')
# Out:
# 7600
# 7600
# labels : ['0', '3', '6', '4', '5', 'div', 'sub', '2', 'mul', '1', '8', '9', 'add', '7']

# %%
figure = plt.figure(figsize=(10, 10))
j = 0
for i in list(set(y)):
    idx = y.index(i)
    img = x[idx]
    img = cv2.resize(img, (256, 256))
    figure.add_subplot(5, 5, j+1)
    plt.imshow(img)
    plt.axis('off')
    plt.title(i)
    j += 1

# %%
unique, count = np.unique(y, return_counts=True)
figure = plt.figure(figsize=(20, 10))
sn.barplot(unique, count).set_title('Number of Images per Category')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
X = []
for i in range(len(x)):
#     print(i)
    img = x[i]
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    threshold_image = cv2.threshold(img_gray, 0, 255, cv2.THRESH_BINARY_INV|cv2.THRESH_OTSU)[1]
    threshold_image = cv2.resize(threshold_image, (32, 32))
    X.append(threshold_image)
print(len(X))
# Out:
# 7600

# %%
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)
print(len(y))
# Out:
# 7600

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.2)

# %%
unique_train, count_train = np.unique(Y_train, return_counts=True)
figure = plt.figure(figsize=(20, 10))
sn.barplot(unique_train, count_train).set_title('Number of Images per category in Train Set')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
unique_test, count_test = np.unique(Y_test, return_counts=True)
figure = plt.figure(figsize=(20, 10))
sn.barplot(unique_test, count_test).set_title('Number of Images per category in Test Set')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
X_train = np.array(X_train)
X_test = np.array(X_test)
Y_train = np.array(Y_train)
Y_test = np.array(Y_test)

Y_train = to_categorical(Y_train)
Y_test = to_categorical(Y_test)
X_train = np.expand_dims(X_train, axis=-1)
X_test = np.expand_dims(X_test, axis=-1)
X_train = X_train/255.
X_test = X_test/255.

print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (6080, 32, 32, 1)
# (1520, 32, 32, 1)
# (6080, 14)
# (1520, 14)

# %%
def math_symbol_and_digits_recognition(input_shape=(32, 32, 1)):
    regularizer = l2(0.01)
    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(Conv2D(32, (3, 3), strides=(1, 1), padding='same', 
                     kernel_initializer=glorot_uniform(seed=0), 
                     name='conv1', activity_regularizer=regularizer))
    model.add(Activation(activation='relu', name='act1'))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    model.add(Conv2D(32, (3, 3), strides=(1, 1), padding='same', 
                     kernel_initializer=glorot_uniform(seed=0), 
                     name='conv2', activity_regularizer=regularizer))
    model.add(Activation(activation='relu', name='act2'))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    model.add(Conv2D(64, (3, 3), strides=(1, 1), padding='same', 
                     kernel_initializer=glorot_uniform(seed=0), 
                     name='conv3', activity_regularizer=regularizer))
    model.add(Activation(activation='relu', name='act3'))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    model.add(Flatten())
    model.add(Dropout(0.5))
    model.add(Dense(120, activation='relu', kernel_initializer=glorot_uniform(seed=0), name='fc1'))
    model.add(Dense(84, activation='relu', kernel_initializer=glorot_uniform(seed=0), name='fc2'))
    model.add(Dense(14, activation='softmax', kernel_initializer=glorot_uniform(seed=0), name='fc3'))
    
    optimizer = Adam()
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

# %%
model = math_symbol_and_digits_recognition(input_shape=(32, 32, 1))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 32, 32, 32)        320
#
#  act1 (Activation)           (None, 32, 32, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2 (Conv2D)              (None, 16, 16, 32)        9248
#
#  act2 (Activation)           (None, 16, 16, 32)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 32)         0
#  2D)
#
#  conv3 (Conv2D)              (None, 8, 8, 64)          18496
#
#  act3 (Activation)           (None, 8, 8, 64)          0
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dropout (Dropout)           (None, 1024)              0
#
#  fc1 (Dense)                 (None, 120)               123000
#
#  fc2 (Dense)                 (None, 84)                10164
#
#  fc3 (Dense)                 (None, 14)                1190
#
# =================================================================
# Total params: 162,418
# Trainable params: 162,418
# Non-trainable params: 0
# _________________________________________________________________

# %%
def step_decay(epoch):
    initial_learning_rate = 0.001
    dropEvery = 10
    factor = 0.5
    lr = initial_learning_rate*(factor**np.floor((1 + epoch)/dropEvery))
    return float(lr)

checkpoint = ModelCheckpoint('maths_symbol_and_digits_recognition.h5', 
                             monitor='val_loss', save_best_only=True, 
                             verbose=1, mode='min')

callbacks = [checkpoint, LearningRateScheduler(step_decay)]

# %%
aug = ImageDataGenerator(zoom_range=0.1,
#                          rotation_range=5,
                         width_shift_range=0.05,
                         height_shift_range=0.05)
hist = model.fit(aug.flow(X_train, Y_train, batch_size=128), batch_size=128, epochs=100, validation_data=(X_test, Y_test))
# hist2 = model2.fit(X_train, Y_train, batch_size=128, epochs=100, validation_data=(X_test, Y_test), callbacks=callbacks)
# Out:
# Epoch 1/100
# 48/48 [==============================] - 12s 227ms/step - loss: 2.8839 - accuracy: 0.2245 - val_loss: 2.3032 - val_accuracy: 0.4513
# Epoch 2/100
# 48/48 [==============================] - 11s 220ms/step - loss: 1.7399 - accuracy: 0.5671 - val_loss: 1.4289 - val_accuracy: 0.6809
# Epoch 3/100
# 48/48 [==============================] - 10s 215ms/step - loss: 1.2129 - accuracy: 0.7082 - val_loss: 1.1418 - val_accuracy: 0.7553
# Epoch 4/100
# 48/48 [==============================] - 10s 215ms/step - loss: 0.9843 - accuracy: 0.7645 - val_loss: 1.0415 - val_accuracy: 0.7632
# Epoch 5/100
# 48/48 [==============================] - 10s 216ms/step - loss: 0.8161 - accuracy: 0.8160 - val_loss: 0.9661 - val_accuracy: 0.7803
# Epoch 6/100
# 48/48 [==============================] - 11s 234ms/step - loss: 0.7380 - accuracy: 0.8352 - val_loss: 0.8015 - val_accuracy: 0.8467
# Epoch 7/100
# 48/48 [==============================] - 10s 217ms/step - loss: 0.6690 - accuracy: 0.8543 - val_loss: 0.7444 - val_accuracy: 0.8599
# Epoch 8/100
# 48/48 [==============================] - 10s 216ms/step - loss: 0.6023 - accuracy: 0.8641 - val_loss: 0.6672 - val_accuracy: 0.8796
# Epoch 9/100
# 48/48 [==============================] - 13s 273ms/step - loss: 0.5455 - accuracy: 0.8839 - val_loss: 0.6024 - val_accuracy: 0.8928
# Epoch 10/100
# 48/48 [==============================] - 13s 266ms/step - loss: 0.5122 - accuracy: 0.8919 - val_loss: 0.5004 - val_accuracy: 0.9191
# Epoch 11/100
# 48/48 [==============================] - 11s 223ms/step - loss: 0.4834 - accuracy: 0.9007 - val_loss: 0.5261 - val_accuracy: 0.9013
# Epoch 12/100
# 48/48 [==============================] - 11s 228ms/step - loss: 0.4523 - accuracy: 0.9002 - val_loss: 0.4893 - val_accuracy: 0.9072
# Epoch 13/100
# 48/48 [==============================] - 11s 220ms/step - loss: 0.4288 - accuracy: 0.9109 - val_loss: 0.5708 - val_accuracy: 0.8993
# Epoch 14/100
# 48/48 [==============================] - 11s 221ms/step - loss: 0.4141 - accuracy: 0.9132 - val_loss: 0.6045 - val_accuracy: 0.8743
# Epoch 15/100
# 48/48 [==============================] - 11s 219ms/step - loss: 0.3903 - accuracy: 0.9220 - val_loss: 0.4710 - val_accuracy: 0.9158
# Epoch 16/100
# 48/48 [==============================] - 11s 220ms/step - loss: 0.3523 - accuracy: 0.9283 - val_loss: 0.4631 - val_accuracy: 0.9151
# Epoch 17/100
# 48/48 [==============================] - 10s 218ms/step - loss: 0.3625 - accuracy: 0.9224 - val_loss: 0.5461 - val_accuracy: 0.8868
# Epoch 18/100
# 48/48 [==============================] - 11s 219ms/step - loss: 0.3539 - accuracy: 0.9252 - val_loss: 0.4509 - val_accuracy: 0.9191
# Epoch 19/100
# 48/48 [==============================] - 10s 218ms/step - loss: 0.3124 - accuracy: 0.9385 - val_loss: 0.3548 - val_accuracy: 0.9428
# Epoch 20/100
# 48/48 [==============================] - 12s 251ms/step - loss: 0.2998 - accuracy: 0.9391 - val_loss: 0.3728 - val_accuracy: 0.9401
# Epoch 21/100
# 48/48 [==============================] - 10s 216ms/step - loss: 0.2968 - accuracy: 0.9370 - val_loss: 0.3545 - val_accuracy: 0.9349
# Epoch 22/100
# 48/48 [==============================] - 11s 224ms/step - loss: 0.2852 - accuracy: 0.9414 - val_loss: 0.3792 - val_accuracy: 0.9322
# Epoch 23/100
# 48/48 [==============================] - 12s 240ms/step - loss: 0.2869 - accuracy: 0.9444 - val_loss: 0.3606 - val_accuracy: 0.9362
# Epoch 24/100
# 48/48 [==============================] - 12s 240ms/step - loss: 0.2717 - accuracy: 0.9416 - val_loss: 0.2916 - val_accuracy: 0.9546
# Epoch 25/100
# 48/48 [==============================] - 10s 216ms/step - loss: 0.2620 - accuracy: 0.9493 - val_loss: 0.2799 - val_accuracy: 0.9526
# Epoch 26/100
# 48/48 [==============================] - 12s 240ms/step - loss: 0.2434 - accuracy: 0.9526 - val_loss: 0.3133 - val_accuracy: 0.9467
# Epoch 27/100
# 48/48 [==============================] - 13s 261ms/step - loss: 0.2476 - accuracy: 0.9497 - val_loss: 0.2793 - val_accuracy: 0.9546
# Epoch 28/100
# 48/48 [==============================] - 11s 220ms/step - loss: 0.2326 - accuracy: 0.9567 - val_loss: 0.2869 - val_accuracy: 0.9487
# Epoch 29/100
# 48/48 [==============================] - 11s 219ms/step - loss: 0.2307 - accuracy: 0.9530 - val_loss: 0.3680 - val_accuracy: 0.9263
# Epoch 30/100
# 48/48 [==============================] - 10s 218ms/step - loss: 0.2328 - accuracy: 0.9515 - val_loss: 0.2569 - val_accuracy: 0.9605
# Epoch 31/100
# 48/48 [==============================] - 11s 219ms/step - loss: 0.2210 - accuracy: 0.9541 - val_loss: 0.2612 - val_accuracy: 0.9507
# Epoch 32/100
# 48/48 [==============================] - 11s 219ms/step - loss: 0.2229 - accuracy: 0.9533 - val_loss: 0.2959 - val_accuracy: 0.9546
# Epoch 33/100
# 48/48 [==============================] - 11s 226ms/step - loss: 0.2040 - accuracy: 0.9618 - val_loss: 0.2490 - val_accuracy: 0.9579
# Epoch 34/100
# 48/48 [==============================] - 11s 233ms/step - loss: 0.1917 - accuracy: 0.9640 - val_loss: 0.2320 - val_accuracy: 0.9658
# Epoch 35/100
# 48/48 [==============================] - 11s 221ms/step - loss: 0.1950 - accuracy: 0.9607 - val_loss: 0.2973 - val_accuracy: 0.9480
# Epoch 36/100
# 48/48 [==============================] - 11s 220ms/step - loss: 0.2135 - accuracy: 0.9523 - val_loss: 0.2783 - val_accuracy: 0.9500
# Epoch 37/100
# 48/48 [==============================] - 11s 221ms/step - loss: 0.1828 - accuracy: 0.9678 - val_loss: 0.2075 - val_accuracy: 0.9711
# Epoch 38/100
# 48/48 [==============================] - 11s 222ms/step - loss: 0.1845 - accuracy: 0.9628 - val_loss: 0.2319 - val_accuracy: 0.9632
# Epoch 39/100
# 48/48 [==============================] - 11s 219ms/step - loss: 0.1844 - accuracy: 0.9635 - val_loss: 0.2944 - val_accuracy: 0.9487
# Epoch 40/100
# 48/48 [==============================] - 11s 227ms/step - loss: 0.1875 - accuracy: 0.9617 - val_loss: 0.3283 - val_accuracy: 0.9283
# Epoch 41/100
# 48/48 [==============================] - 11s 218ms/step - loss: 0.1758 - accuracy: 0.9628 - val_loss: 0.2344 - val_accuracy: 0.9632
# Epoch 42/100
# 48/48 [==============================] - 11s 219ms/step - loss: 0.1727 - accuracy: 0.9627 - val_loss: 0.2064 - val_accuracy: 0.9704
# Epoch 43/100
# 48/48 [==============================] - 11s 219ms/step - loss: 0.1843 - accuracy: 0.9645 - val_loss: 0.2697 - val_accuracy: 0.9447
# Epoch 44/100
# 48/48 [==============================] - 10s 217ms/step - loss: 0.1715 - accuracy: 0.9637 - val_loss: 0.2057 - val_accuracy: 0.9664
# Epoch 45/100
# 48/48 [==============================] - 10s 215ms/step - loss: 0.1718 - accuracy: 0.9678 - val_loss: 0.1912 - val_accuracy: 0.9743
# Epoch 46/100
# 48/48 [==============================] - 10s 216ms/step - loss: 0.1573 - accuracy: 0.9707 - val_loss: 0.1869 - val_accuracy: 0.9697
# Epoch 47/100
# 48/48 [==============================] - 10s 216ms/step - loss: 0.1495 - accuracy: 0.9719 - val_loss: 0.2122 - val_accuracy: 0.9645
# Epoch 48/100
# 48/48 [==============================] - 10s 217ms/step - loss: 0.1600 - accuracy: 0.9673 - val_loss: 0.2163 - val_accuracy: 0.9605
# Epoch 49/100
# 48/48 [==============================] - 10s 217ms/step - loss: 0.1520 - accuracy: 0.9686 - val_loss: 0.1891 - val_accuracy: 0.9711
# Epoch 50/100
# 48/48 [==============================] - 11s 219ms/step - loss: 0.1433 - accuracy: 0.9724 - val_loss: 0.1929 - val_accuracy: 0.9684
# Epoch 51/100
# 48/48 [==============================] - 11s 222ms/step - loss: 0.1443 - accuracy: 0.9717 - val_loss: 0.2187 - val_accuracy: 0.9599
# Epoch 52/100
# 48/48 [==============================] - 11s 220ms/step - loss: 0.1502 - accuracy: 0.9722 - val_loss: 0.2059 - val_accuracy: 0.9651
# Epoch 53/100
# 48/48 [==============================] - 11s 229ms/step - loss: 0.1415 - accuracy: 0.9725 - val_loss: 0.1815 - val_accuracy: 0.9717
# Epoch 54/100
# 48/48 [==============================] - 11s 228ms/step - loss: 0.1376 - accuracy: 0.9750 - val_loss: 0.2018 - val_accuracy: 0.9638
# Epoch 55/100
# 48/48 [==============================] - 11s 231ms/step - loss: 0.1367 - accuracy: 0.9732 - val_loss: 0.2047 - val_accuracy: 0.9664
# Epoch 56/100
# 48/48 [==============================] - 11s 227ms/step - loss: 0.1303 - accuracy: 0.9760 - val_loss: 0.1478 - val_accuracy: 0.9770
# Epoch 57/100
# 48/48 [==============================] - 11s 225ms/step - loss: 0.1534 - accuracy: 0.9671 - val_loss: 0.1708 - val_accuracy: 0.9757
# Epoch 58/100
# 48/48 [==============================] - 11s 226ms/step - loss: 0.1307 - accuracy: 0.9760 - val_loss: 0.2068 - val_accuracy: 0.9618
# Epoch 59/100
# 48/48 [==============================] - 11s 226ms/step - loss: 0.1239 - accuracy: 0.9762 - val_loss: 0.1843 - val_accuracy: 0.9671
# Epoch 60/100
# 48/48 [==============================] - 11s 224ms/step - loss: 0.1255 - accuracy: 0.9758 - val_loss: 0.1907 - val_accuracy: 0.9638
# Epoch 61/100
# 48/48 [==============================] - 11s 221ms/step - loss: 0.1166 - accuracy: 0.9791 - val_loss: 0.1706 - val_accuracy: 0.9678
# Epoch 62/100
# 48/48 [==============================] - 11s 218ms/step - loss: 0.1169 - accuracy: 0.9796 - val_loss: 0.1513 - val_accuracy: 0.9770
# Epoch 63/100
# 48/48 [==============================] - 11s 223ms/step - loss: 0.1187 - accuracy: 0.9785 - val_loss: 0.1774 - val_accuracy: 0.9671
# Epoch 64/100
# 48/48 [==============================] - 11s 222ms/step - loss: 0.1192 - accuracy: 0.9780 - val_loss: 0.1876 - val_accuracy: 0.9724
# Epoch 65/100
# 48/48 [==============================] - 11s 220ms/step - loss: 0.1163 - accuracy: 0.9786 - val_loss: 0.1562 - val_accuracy: 0.9783
# Epoch 66/100
# 48/48 [==============================] - 11s 222ms/step - loss: 0.1234 - accuracy: 0.9768 - val_loss: 0.2023 - val_accuracy: 0.9678
# Epoch 67/100
# 48/48 [==============================] - 11s 220ms/step - loss: 0.1170 - accuracy: 0.9775 - val_loss: 0.1790 - val_accuracy: 0.9697
# Epoch 68/100
# 48/48 [==============================] - 11s 220ms/step - loss: 0.1154 - accuracy: 0.9791 - val_loss: 0.1457 - val_accuracy: 0.9763
# Epoch 69/100
# 48/48 [==============================] - 11s 219ms/step - loss: 0.1018 - accuracy: 0.9814 - val_loss: 0.1675 - val_accuracy: 0.9651
# Epoch 70/100
# 48/48 [==============================] - 11s 222ms/step - loss: 0.1256 - accuracy: 0.9757 - val_loss: 0.2538 - val_accuracy: 0.9579
# Epoch 71/100
# 48/48 [==============================] - 11s 219ms/step - loss: 0.1191 - accuracy: 0.9788 - val_loss: 0.2183 - val_accuracy: 0.9553
# Epoch 72/100
# 48/48 [==============================] - 11s 220ms/step - loss: 0.1218 - accuracy: 0.9771 - val_loss: 0.1399 - val_accuracy: 0.9809
# Epoch 73/100
# 48/48 [==============================] - 11s 220ms/step - loss: 0.1140 - accuracy: 0.9766 - val_loss: 0.1436 - val_accuracy: 0.9803
# Epoch 74/100
# 48/48 [==============================] - 11s 220ms/step - loss: 0.1141 - accuracy: 0.9773 - val_loss: 0.1332 - val_accuracy: 0.9809
# Epoch 75/100
# 48/48 [==============================] - 11s 219ms/step - loss: 0.1102 - accuracy: 0.9793 - val_loss: 0.1389 - val_accuracy: 0.9796
# Epoch 76/100
# 48/48 [==============================] - 10s 217ms/step - loss: 0.1008 - accuracy: 0.9817 - val_loss: 0.1484 - val_accuracy: 0.9776
# Epoch 77/100
# 48/48 [==============================] - 10s 217ms/step - loss: 0.0997 - accuracy: 0.9811 - val_loss: 0.1264 - val_accuracy: 0.9809
# Epoch 78/100
# 48/48 [==============================] - 10s 218ms/step - loss: 0.1168 - accuracy: 0.9743 - val_loss: 0.1567 - val_accuracy: 0.9730
# Epoch 79/100
# 48/48 [==============================] - 11s 219ms/step - loss: 0.0979 - accuracy: 0.9836 - val_loss: 0.1505 - val_accuracy: 0.9763
# Epoch 80/100
# 48/48 [==============================] - 11s 220ms/step - loss: 0.1007 - accuracy: 0.9832 - val_loss: 0.1417 - val_accuracy: 0.9776
# Epoch 81/100
# 48/48 [==============================] - 11s 219ms/step - loss: 0.1012 - accuracy: 0.9811 - val_loss: 0.1227 - val_accuracy: 0.9836
# Epoch 82/100
# 48/48 [==============================] - 10s 217ms/step - loss: 0.0892 - accuracy: 0.9855 - val_loss: 0.1212 - val_accuracy: 0.9816
# Epoch 83/100
# 48/48 [==============================] - 10s 217ms/step - loss: 0.0981 - accuracy: 0.9819 - val_loss: 0.1243 - val_accuracy: 0.9796
# Epoch 84/100
# 48/48 [==============================] - 10s 217ms/step - loss: 0.0940 - accuracy: 0.9819 - val_loss: 0.1712 - val_accuracy: 0.9658
# Epoch 85/100
# 48/48 [==============================] - 10s 218ms/step - loss: 0.0948 - accuracy: 0.9832 - val_loss: 0.1199 - val_accuracy: 0.9822
# Epoch 86/100
# 48/48 [==============================] - 11s 221ms/step - loss: 0.0969 - accuracy: 0.9806 - val_loss: 0.1324 - val_accuracy: 0.9743
# Epoch 87/100
# 48/48 [==============================] - 11s 220ms/step - loss: 0.0872 - accuracy: 0.9844 - val_loss: 0.1579 - val_accuracy: 0.9671
# Epoch 88/100
# 48/48 [==============================] - 10s 218ms/step - loss: 0.0919 - accuracy: 0.9829 - val_loss: 0.1247 - val_accuracy: 0.9796
# Epoch 89/100
# 48/48 [==============================] - 10s 218ms/step - loss: 0.0870 - accuracy: 0.9862 - val_loss: 0.1211 - val_accuracy: 0.9829
# Epoch 90/100
# 48/48 [==============================] - 10s 218ms/step - loss: 0.0937 - accuracy: 0.9806 - val_loss: 0.1265 - val_accuracy: 0.9789
# Epoch 91/100
# 48/48 [==============================] - 10s 218ms/step - loss: 0.1071 - accuracy: 0.9798 - val_loss: 0.1207 - val_accuracy: 0.9809
# Epoch 92/100
# 48/48 [==============================] - 10s 218ms/step - loss: 0.0854 - accuracy: 0.9852 - val_loss: 0.1115 - val_accuracy: 0.9822
# Epoch 93/100
# 48/48 [==============================] - 11s 219ms/step - loss: 0.0976 - accuracy: 0.9798 - val_loss: 0.1460 - val_accuracy: 0.9730
# Epoch 94/100
# 48/48 [==============================] - 10s 218ms/step - loss: 0.1028 - accuracy: 0.9791 - val_loss: 0.1288 - val_accuracy: 0.9816
# Epoch 95/100
# 48/48 [==============================] - 11s 220ms/step - loss: 0.1043 - accuracy: 0.9826 - val_loss: 0.1902 - val_accuracy: 0.9684
# Epoch 96/100
# 48/48 [==============================] - 11s 219ms/step - loss: 0.0908 - accuracy: 0.9842 - val_loss: 0.1391 - val_accuracy: 0.9776
# Epoch 97/100
# 48/48 [==============================] - 11s 219ms/step - loss: 0.0811 - accuracy: 0.9854 - val_loss: 0.1316 - val_accuracy: 0.9796
# Epoch 98/100
# 48/48 [==============================] - 11s 219ms/step - loss: 0.0784 - accuracy: 0.9872 - val_loss: 0.1150 - val_accuracy: 0.9836
# Epoch 99/100
# 48/48 [==============================] - 11s 218ms/step - loss: 0.0913 - accuracy: 0.9816 - val_loss: 0.1348 - val_accuracy: 0.9743
# Epoch 100/100
# 48/48 [==============================] - 11s 219ms/step - loss: 0.0790 - accuracy: 0.9872 - val_loss: 0.1122 - val_accuracy: 0.9842

# %%
figure = plt.figure(figsize=(10, 10))
plt.plot(hist.history['accuracy'], label='Train Set Accuracy')
plt.plot(hist.history['val_accuracy'], label='Test Set Accuracy')
plt.title('Accuracy Plot')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='upper right')
plt.show()

figure2 = plt.figure(figsize=(10, 10))
plt.plot(hist.history['loss'], label='Train Set Loss')
plt.plot(hist.history['val_loss'], label='Test Set Loss')
plt.title('Loss Plot')
plt.xlabel('Epochs')
plt.ylabel('Loss Value')
plt.legend(loc='upper right')
plt.show()

# %%
ypred = model.predict(X_test)
ypred = np.argmax(ypred, axis=1)
Y_test_hat = np.argmax(Y_test, axis=1)
print(classification_report(Y_test_hat, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.96       128
#            1       0.99      0.95      0.97       124
#            2       0.98      0.99      0.98        84
#            3       0.98      1.00      0.99        97
#            4       0.98      0.96      0.97       109
#            5       1.00      1.00      1.00        81
#            6       0.93      1.00      0.97        83
#            7       0.98      0.99      0.98        97
#            8       0.98      0.99      0.99       110
#            9       0.96      0.97      0.96       113
#           10       1.00      0.99      1.00       131
#           11       1.00      1.00      1.00       102
#           12       1.00      1.00      1.00       121
#           13       1.00      1.00      1.00       140
#
#     accuracy                           0.98      1520
#    macro avg       0.98      0.99      0.98      1520
# weighted avg       0.98      0.98      0.98      1520
